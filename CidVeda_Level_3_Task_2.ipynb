# %%
#install Google Drive library
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
#import dataset into CoLab
df = pd.read_csv('/content/gdrive/MyDrive/CocVeda/Data Set For Task/3) Sentiment dataset.csv')

# %%
# Explore data records, First 5 rows
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#Explore data records, last 5 rows
df.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
# View a random sample of 5 rows (The Sample)
display(df.sample(5))
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 585           586         590
# 499           500         504
# 440           441         445
# 102           103         105
# 655           656         660
#
#                                                   Text       Sentiment  \
# 585  Got dressed for the day, then remembered it's ...   Indifference
# 499  At the summit of Machu Picchu, a breathtaking ...            Awe
# 440  Shattered by the echoes of a shattered dream, ...     Desolation
# 102   Feeling bitter about the unfairness in the wo...   Bitter
# 655  Mastering the art of the perfect doodle during...            Joy
#
#                Timestamp                      User    Platform  \
# 585  2023-05-25 19:00:00           FashionBlunder    Facebook
# 499  2017-11-05 22:00:00    MachuPicchuAdventurer    Facebook
# 440  2017-09-10 19:15:00              DreamEchoes     Twitter
# 102  2023-03-01 17:45:00          WorkplaceWoes      Twitter
# ...

# %%
#Data dimension
df.shape
# Out:
# (732, 15)

# %%
#explore datatype
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
# List all column names for reference
print(df.columns.tolist())
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour']

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
# Summary statistics
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
# Step 2: Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
from wordcloud import WordCloud

# %%
# Step 3: Download Necessary NLTK Resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# Step 4: Load the Dataset from Google Drive
file_path = "/content/gdrive/MyDrive/CocVeda/Data Set For Task/3) Sentiment dataset.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
# Step 5: Inspect Dataset Structure and Columns
df.info()
df.columns

# %%
# Step 6: Select Text Column (Modify Column Name if Needed)
# Reload the DataFrame to ensure all original columns are present
df = pd.read_csv(file_path)

# The actual text content is in the 'Text' column, not 'Unnamed: 0.1'
text_column_name = 'Text' # Assuming 'Text' is the correct column name for the text data
df = df[[text_column_name]].copy() # Create a copy to avoid SettingWithCopyWarning
df.rename(columns={text_column_name: "text"}, inplace=True)

df.head()
# Out:
#                                                 text
# 0   Enjoying a beautiful day at the park!        ...
# 1   Traffic was terrible this morning.           ...
# 2   Just finished an amazing workout! 💪          ...
# 3   Excited about the upcoming weekend getaway!  ...
# 4   Trying out a new recipe for dinner tonight.  ...

# %%
# Step 7: Text Preprocessing (Lowercase, Remove Punctuation, Stopwords, Lemmatization)
import nltk
nltk.download('wordnet') # Ensure wordnet is downloaded for this cell

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = str(text).lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return " ".join(tokens)

df["clean_text"] = df["text"].apply(preprocess_text)

df.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                                 text  \
# 0   Enjoying a beautiful day at the park!        ...
# 1   Traffic was terrible this morning.           ...
# 2   Just finished an amazing workout! 💪          ...
# 3   Excited about the upcoming weekend getaway!  ...
# 4   Trying out a new recipe for dinner tonight.  ...
#
#                          clean_text
# 0       enjoying beautiful day park
# 1          traffic terrible morning
# 2        finished amazing workout 💪
# 3  excited upcoming weekend getaway
# 4  trying new recipe dinner tonight

# %%
#  Step 8: Perform Sentiment Analysis Using TextBlob
from textblob import TextBlob
def get_sentiment(text):
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df["sentiment"] = df["clean_text"].apply(get_sentiment)

df.head()
# Out:
#                                                 text  \
# 0   Enjoying a beautiful day at the park!        ...
# 1   Traffic was terrible this morning.           ...
# 2   Just finished an amazing workout! 💪          ...
# 3   Excited about the upcoming weekend getaway!  ...
# 4   Trying out a new recipe for dinner tonight.  ...
#
#                          clean_text sentiment
# 0       enjoying beautiful day park  Positive
# 1          traffic terrible morning  Negative
# 2        finished amazing workout 💪  Positive
# 3  excited upcoming weekend getaway  Positive
# 4  trying new recipe dinner tonight  Positive

# %%
# Step 9: Visualize Sentiment Distribution
sentiment_counts = df["sentiment"].value_counts()

import matplotlib.pyplot as plt
plt.figure()
sentiment_counts.plot(kind='bar')
plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
# Step 10: Generate Word Cloud for All Text Data
from wordcloud import WordCloud
all_words = " ".join(df["clean_text"])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_words)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - All Reviews")
plt.show()

# %%
# Step 11: Generate Word Clouds for Each Sentiment Category
for sentiment in df["sentiment"].unique():
    text_data = " ".join(df[df["sentiment"] == sentiment]["clean_text"])

    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)

    plt.figure()
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Word Cloud - {sentiment} Reviews")
    plt.show()

# %%
# Step 12: Save Final Dataset with Sentiment Labels
# Modified the output path to a writable location within MyDrive
output_path = "/content/gdrive/MyDrive/sentiment_analysis_output.csv"
df.to_csv(output_path, index=False)

print("Sentiment analysis completed and file saved successfully.")
# Out:
# Sentiment analysis completed and file saved successfully.
